# %% [markdown]
# # word_list_tools repo
#
# by David Taylor, www.prooffreader.com, prooffreader@gmail.com
#
# a collection of tools to create and analyze lists of words using python with pandas and matplotlib

# %% [markdown]
# ## letter_distributions_comparison
#
# a modification of letter_distributions to compare two or more languages
#
# determine letter distributions within the word based on a word list with frequencies
#
# word list is pandas dataframe with columns 'word' and 'freq'. Any other columns will be ignored.
#
# ** initial_data_munge must be run first to create pickled dataframes of word lists **

# %%
language_list = ['English', 'French', 'German', 'Spanish', 'Italian', 'Portuguese', 'Polish', 'Finnish']

lang_quant = len(language_list)
                 
data_path = 'data/Europarl'
nb_path = 'letter_dist_comparison'

import pandas as pd
import os
import pickle

colors = [[0, '#ffffcc'],
          [0.1, '#ffeda0'],
          [0.5, '#fed976'],
          [1, '#feb24c'],
          [2, '#fd8d3c'],
          [3, '#fc4e2a'],
          [5, '#e31a1c'],
          [9, '#b10026']]

alphabet = 'abcdefghijklmnopqrstuvwxyz'

# List 'colors' is assigned by user, with nested lists of lower boundary (the first should normally be zero) 
# and hex color string. The bins follow the usual [low inclusive, high exclusive) python boundaries.
# The maximum value is calculated for the user.

# %% [raw]
# create one letters dataframe for each language, with frequency of letters in number of bins determined by user

# %%
redo_letters_pickles = False # If True, will always recalculate letters dataframe and overwrite pickle.
                             # If False, will perform calculations if pickle file does not exist.

b_len = 15 #number of bins, decided by user

for language in language_list:

    letters_pickle = nb_path + '/' + language + '_letters.pickle'
    
    if not os.path.isfile(letters_pickle) or redo_letters_pickles == True:
    
        print 'Calculating', language, 'letters dataframe.'
        
        words = pd.read_pickle(data_path + "/" + language + ".pickle")
    
        p_step = b_len # to facilitate readability; cross product
        
        # dataframe for results; z is just a temporary list to facilitate dataframe initialization
        z = [0] * b_len
        letters = pd.DataFrame({'a': z, 'b': z, 'c': z, 'd': z, 'e': z, 'f': z, 'g': z, 
                                'h': z, 'i': z, 'j': z, 'k': z, 'l': z, 'm': z, 'n': z, 
                                'o': z, 'p': z, 'q': z, 'r': z, 's': z, 't': z, 'u': z, 
                                'v': z, 'w': z, 'x': z, 'y': z, 'z': z})
        
        for i in range(len(words)):
            freq = words.freq.iloc[i]
            wd = words.word.iloc[i]
            p_len = len(wd)
            b_step = p_len
            bp_mult = b_len * p_len #use multiple instead of range of 0 to 1 (or 0 to 100) to avoid floats not adding together exactly
            b_curnum = 0 # current bin
            p_curnum = 0 # current letter
            curmult = 0 # current position of algorithm from 0 to bp_mult
            temp = 0
        
            if p_len > 1:
                while curmult < bp_mult:
                    temp += 1
                    overlap = min((b_curnum + 1) * b_step, (p_curnum + 1) * p_step) - curmult
                    #try:
                    letters[wd[p_curnum]][b_curnum] += freq * overlap / bp_mult
                    curmult += overlap
                    if (b_curnum + 1) * b_step == curmult:
                        b_curnum += 1
                    if (p_curnum + 1) * p_step == curmult:
                        p_curnum += 1
                    if temp >= 100:
                        print "Error; more than 100 iterations on word " + wd
                        break
            
        letters.to_pickle(letters_pickle)
# Out:
# Calculating German letters dataframe.
# Calculating
#  Spanish letters dataframe.
# Calculating
#  Italian letters dataframe.
# Calculating
#  Portuguese letters dataframe.
# Calculating
#  Polish letters dataframe.
# Calculating
#  Finnish letters dataframe.

# %% [markdown]
# Dataframes with bins as rows and letters as columns. Bin number equals row number, so iloc can be used to look up values.
#
#     * letters (raw frequencies)
#     * letters_norm (frequencies normalized so that each letter's maximum has a value of 100; integers, not floats)
#     * letters_equal_area (letters_norm adjusted so that the area under the slope is  the same for all graphs)
#
# Dataframe 'letters_stats' has statistics for each letter, the row indexes are the letters. Columns are:
#
#     * max_freq: maximum raw frequency of each letter
#     * max_bin: bin where max_freq occurs
#     * total_freq: the total frequency of each letter
#     * pct_freq: the total frequency as a percent of all letters; for representative English word lists, e is the top letter at about 12 percent
#     * area_under_norm: area under normalized lines
#
# Dict 'letters_overall' has statistics for the entire dataset;
#
#     * max_freq: the maximum raw frequency of any letter
#     * max_letter: the letter with the maximum raw frequency
#     * total_freq:
#     * max_pct:

# %% [markdown]
# #### Process each language in turn and show summary statistics.

# %%
redo_summary_pickle = True

for language in language_list:

    letters_pickle = nb_path + '/' + language + '_letters.pickle'
    letters = pd.read_pickle(letters_pickle)    

    letters_norm = letters.copy() # note that values are kept as integers for now; the graphs are narrow enough that it should not matter
    letters_equal_area = letters.copy() 
    letters_overall = {}
    
    letters_stats = pd.DataFrame({'max_freq': [0] * 26}, index=list(alphabet))
    letters_stats['max_bin'] = 0
    letters_stats['total_freq'] = 0
    letters_stats['pct_freq'] = 0.0
    letters_stats['norm_area'] = 0
    letters_stats['color'] = ''
    
    for ltr in alphabet:
        letters_stats.max_freq.ix[ltr] = letters[ltr].max()
        letters_stats.max_bin.ix[ltr] = letters[letters[ltr] == letters_stats.max_freq.ix[ltr]].index[0]
        letters_stats.total_freq.ix[ltr] = letters[ltr].sum()
    
    letters_overall['max_freq'] = letters_stats.max_freq.max()
    letters_overall['total_freq'] = letters_stats.total_freq.sum()
    letters_overall['max_letter'] = letters_stats[letters_stats.max_freq == letters_overall['max_freq']].iloc[0].name
    
    for ltr in alphabet:
        letters_stats.pct_freq.ix[ltr] = (letters_stats.total_freq.ix[ltr] * 100.0
                                          / letters_overall['total_freq'])
        for rw in range(len(letters_norm)):
            letters_norm[ltr].iloc[rw] *= 100
            letters_norm[ltr].iloc[rw] /= letters_stats['max_freq'].ix[ltr]
        
    letters_overall['max_pct'] = letters_stats.pct_freq.max()
    
    for ltr in alphabet:
        # assign colors based on pct_max and color list
        color = ''
        for i in range(len(colors)):
            if letters_stats.pct_freq.ix[ltr] >= colors[i][0]:
                 color = colors[i][1]
        letters_stats.color.ix[ltr] = color
        # calculate area under norm lines
        area = 0
        for rw in range(len(letters_norm) - 1):
            height0 = letters_norm[ltr].iloc[rw]
            height1 = letters_norm[ltr].iloc[rw+1]
            area += min(height0, height1)
            area += 0.5 * abs(height1 - height0)
        letters_stats.norm_area[ltr] = area
    
    letters_overall['max_area'] = letters_stats.norm_area.max()    
    letters_overall['max_equal_area'] = 0
    
    for ltr in alphabet:
        for rw in range(len(letters_equal_area)):
            letters_equal_area[ltr].iloc[rw] = (letters_norm[ltr].iloc[rw] * 
                                                letters_overall['max_area'] / letters_stats.norm_area[ltr])
        letters_overall['max_equal_area'] = max(letters_overall['max_equal_area'], letters_equal_area[ltr].max())
    
    #rescale to 100
    for ltr in alphabet:
        for rw in range(len(letters_equal_area)):
            letters_equal_area[ltr].iloc[rw] *= 100
            letters_equal_area[ltr].iloc[rw] /= letters_overall['max_equal_area']
            
    import math
    letters_overall['max_pct_for_legend'] = int(math.ceil(letters_overall['max_pct']))
    
    letters_overall['max_compromise'] = 0
    letters_compromise = letters_norm.copy()
    for ltr in alphabet:
        for rw in range(len(letters_equal_area)):
            letters_compromise[ltr].iloc[rw] = (letters_norm[ltr].iloc[rw] + letters_equal_area[ltr].iloc[rw]) / 2
        letters_overall['max_compromise'] = max(letters_overall['max_compromise'], letters_compromise[ltr].max())
        
    #rescale to 100
    for ltr in alphabet:
        for rw in range(len(letters_equal_area)):
            letters_compromise[ltr].iloc[rw] *= 100
            letters_compromise[ltr].iloc[rw] /= letters_overall['max_compromise']
    
    print "\nLanguage: ", language
    print "letters['a']:"
    print letters['a']
    print "\nletters_norm['a']:"
    print letters_norm['a']
    print "\nletters_equal_area['a']:"
    print letters_equal_area['a']
    print "\nletters_compromise['a']:"
    print letters_compromise['a']
    print "\nletters_stats:"
    print letters_stats
    print "\nLetters_overall:"
    print letters_overall
    print '\n==================================\n'
    
    letters_norm.to_pickle(nb_path + '/' + language + '_letters_norm.pickle')
    letters_equal_area.to_pickle(nb_path + '/' + language + '_letters_equal_area.pickle')
    letters_compromise.to_pickle(nb_path + '/' + language + '_letters_compromise.pickle')
    pickle.dump(letters_overall, open(nb_path + '/' + language + '_letters_overall.pickle', 'w+'))
    pickle.dump(letters_stats, open(nb_path + '/' + language + '_letters_stats.pickle', 'w+'))
# Out:
# Language:  English
# letters['a']:
# 0     314705
# 1     313244
# 2     310471
# 3     323605
# 4     369285
# 5     269882
# 6     282761
# 7     271177
# 8     258369
# 9     241471
# 10    178229
# 11    120913
# 12     84107
# 13     34889
# 14     15160
# Name: a, dtype: int64
#
# letters_norm['a']:
# 0      85
# 1      84
# 2      84
# 3      87
# 4     100
# 5      73
# 6      76
# 7      73
# 8      69
# 9      65
# 10     48
# 11     32
# 12     22
# 13      9
# 14      4
# Name: a, dtype: int64
#
# letters_equal_area['a']:
# 0     32
# 1     31
# 2     31
# 3     32
# 4     38
# 5     27
# 6     28
# 7     27
# 8     26
# 9     24
# 10    18
# 11    11
# 12     8
# 13     3
# 14     1
# Name: a, dtype: int64
#
# letters_compromise['a']:
# 0     58
# 1     57
# 2     57
# 3     59
# 4     69
# 5     50
# 6     52
# 7     50
# 8     47
# 9     44
# 10    33
# 11    21
# 12    15
# 13     6
# 14     2
# Name: a, dtype: int64
#
# letters_stats:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a    369285        4     3388268   7.474135        866  #e31a1c
# b    125121        0      769809   1.698111        558  #feb24c
# c    167137        0     1023481   2.257683        552  #fd8d3c
# d    249478       14     1405570   3.100528        492  #fc4e2a
# e    715988       12     5560689  12.266249        716  #b10026
# f    141646        9     1544198   3.406326        995  #fc4e2a
# g     84843       14      541539   1.194574        558  #feb24c
# h    472770        5     2788781   6.151734        566  #e31a1c
# i    418522        6     3401038   7.502304        776  #e31a1c
# j      9405        0       46345   0.102232        437  #ffeda0
# k     29509        8      223862   0.493814        702  #ffeda0
# l    139588       11     1408924   3.107926        942  #fc4e2a
# m    109386        1      969717   2.139086        812  #fd8d3c
# n    357240       12     3418795   7.541474        896  #e31a1c
# o    441430        5     4549790  10.036320        977  #b10026
# p    143079        0      741535   1.635742        456  #feb24c
# q      7194        0       30261   0.066752        359  #ffffcc
# r    178703       10     2216313   4.888935       1163  #fc4e2a
# s    386195       14     2696286   5.947701        621  #e31a1c
# t    589748        0     5268782  11.622335        807  #b10026
# u    128491        7     1167564   2.575514        880  #fd8d3c
# v     44053       10      393419   0.867838        859  #fed976
# w    187091        0     1011317   2.230851        476  #fd8d3c
# x     14664        2       57870   0.127655        382  #ffeda0
# y    177385       14      695972   1.535235        330  #feb24c
# z      3166        8       13123   0.028948        396  #ffffcc
#
# Letters_overall:
# {'total_freq': 45333248, 'max_area': 1163, 'max_equal_area': 352, 'max_letter': 'e', 'max_freq': 715988, 'max_compromise': 100, 'max_pct_for_legend': 13, 'max_pct': 12.26624882470367}
#
# ==================================
#
#
# Language:
#  French
# letters['a']:
# 0     162398
# 1     169515
# 2     194406
# 3     200371
# 4     230836
# 5     253411
# 6     246041
# 7     265366
# 8     295663
# 9     298437
# 10    225343
# 11    192897
# 12    164586
# 13    155437
# 14    154383
# Name: a, dtype: int64
#
# letters_norm['a']:
# 0      54
# 1      56
# 2      65
# 3      67
# 4      77
# 5      84
# 6      82
# 7      88
# 8      99
# 9     100
# 10     75
# 11     64
# 12     55
# 13     52
# 14     51
# Name: a, dtype: int64
#
# letters_equal_area['a']:
# 0     17
# 1     18
# 2     21
# 3     22
# 4     25
# 5     27
# 6     27
# 7     29
# 8     32
# 9     33
# 10    24
# 11    21
# 12    18
# 13    17
# 14    16
# Name: a, dtype: int64
#
# letters_compromise['a']:
# 0     35
# 1     37
# 2     43
# 3     44
# 4     51
# 5     55
# 6     54
# 7     58
# 8     65
# 9     66
# 10    49
# 11    42
# 12    36
# 13    34
# 14    33
# Name: a, dtype: int64
#
# letters_stats:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a    298437        9     3209090   7.258591       1016  #e31a1c
# b     31542        0      234768   0.531018        686  #fed976
# c    258361        0     1281463   2.898521        437  #fd8d3c
# d    472085        0     2820530   6.379713        539  #e31a1c
# e    968427       14     9320973  21.082964        889  #b10026
# f     65617        0      333071   0.753368        449  #fed976
# g     25635        0      243171   0.550025        887  #fed976
# h     16425        4      123033   0.278286        713  #ffeda0
# i    290039       10     2370488   5.361770        786  #e31a1c
# j     40249        0      279305   0.631756        638  #fed976
# k      1212        0        9273   0.020974        677  #ffffcc
# l    365988        4     3023596   6.839025        768  #e31a1c
# m    121382        0      978879   2.214111        748  #fd8d3c
# n    328344       12     3137623   7.096941        898  #e31a1c
# o    326118        4     2259487   5.110698        679  #e31a1c
# p    314474        0     1238325   2.800948        336  #fd8d3c
# q    108327        0      604368   1.367011        501  #feb24c
# r    219153       11     2313525   5.232926        982  #e31a1c
# s    723583       14     3759773   8.504172        449  #e31a1c
# t    390463       14     2895525   6.549343        674  #e31a1c
# u    410024        8     3007756   6.803196        711  #e31a1c
# v     61658        5      492608   1.114222        747  #feb24c
# w       458        0        2673   0.006046        518  #ffffcc
# x     36824       14      178105   0.402853        427  #ffeda0
# y     13556        8       71259   0.161180        516  #ffeda0
# z      4934       14       22257   0.050343        380  #ffffcc
#
# Letters_overall:
# {'total_freq': 44210924, 'max_area': 1016, 'max_equal_area': 302, 'max_letter': 'e', 'max_freq': 968427, 'max_compromise': 100, 'max_pct_for_legend': 22, 'max_pct': 21.082963568008665}
#
# ==================================
#
#
# Language:
#  German
# letters['a']:
# 0     193426
# 1     181082
# 2     178598
# 3     234445
# 4     260734
# 5     254455
# 6     235919
# 7     210665
# 8     158593
# 9     155673
# 10     79209
# 11     61523
# 12     42014
# 13     25121
# 14     17560
# Name: a, dtype: int64
#
# letters_norm['a']:
# 0      74
# 1      69
# 2      68
# 3      89
# 4     100
# 5      97
# 6      90
# 7      80
# 8      60
# 9      59
# 10     30
# 11     23
# 12     16
# 13      9
# 14      6
# Name: a, dtype: int64
#
# letters_equal_area['a']:
# 0     20
# 1     19
# 2     19
# 3     25
# 4     27
# 5     27
# 6     25
# 7     22
# 8     16
# 9     16
# 10     8
# 11     6
# 12     4
# 13     2
# 14     1
# Name: a, dtype: int64
#
# letters_compromise['a']:
# 0     47
# 1     44
# 2     43
# 3     57
# 4     63
# 5     62
# 6     57
# 7     51
# 8     38
# 9     37
# 10    19
# 11    14
# 12    10
# 13     5
# 14     3
# Name: a, dtype: int64
#
# letters_stats:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a    260734        4     2289017   5.725562        830  #e31a1c
# b    116134        0      617010   1.543339        471  #feb24c
# c    154522        8      957762   2.395669        613  #fd8d3c
# d    520503        0     3241302   8.107531        554  #e31a1c
# e    649023       12     6554236  16.394237        951  #b10026
# f     54868        0      490776   1.227587        809  #feb24c
# g    104427       14      846761   2.118020        705  #fd8d3c
# h    183224       11     1547745   3.871404        782  #fc4e2a
# i    556252        5     4072469  10.186545        707  #b10026
# j     22006        0       72066   0.180260        270  #ffeda0
# k     72676        0      351815   0.880002        417  #fed976
# l    103668        8      990116   2.476596        915  #fd8d3c
# m    114106        0     1160232   2.902111        919  #fd8d3c
# n    686461       14     4167478  10.424193        545  #b10026
# o    114798        4     1031933   2.581194        875  #fd8d3c
# p     54983        0      225182   0.563252        351  #fed976
# q      1420        0        4094   0.010240        233  #ffffcc
# r    343486       14     3028141   7.574348        817  #e31a1c
# s    246225       14     2754793   6.890617       1026  #e31a1c
# t    281507       14     1807873   4.522068        581  #fc4e2a
# u    190312        2     2020788   5.054636        999  #e31a1c
# v    116683        0      369036   0.923077        258  #fed976
# w    162821        0      697527   1.744738        375  #feb24c
# x      1174        2        9711   0.024290        804  #ffffcc
# y      2322        3       11263   0.028172        463  #ffffcc
# z    101375        0      659776   1.650310        587  #feb24c
#
# Letters_overall:
# {'total_freq': 39978902, 'max_area': 1026, 'max_equal_area': 440, 'max_letter': 'n', 'max_freq': 686461, 'max_compromise': 100, 'max_pct_for_legend': 17, 'max_pct': 16.394237140379694}
#
# ==================================
#
#
# Language:
#  Spanish
# letters['a']:
# 0     162918
# 1     161042
# 2     157657
# 3     193878
# 4     220989
# 5     286151
# 6     269107
# 7     348101
# 8     422444
# 9     453382
# 10    398653
# 11    466761
# 12    544018
# 13    557452
# 14    546385
# Name: a, dtype: int64
#
# letters_norm['a']:
# 0      29
# 1      28
# 2      28
# 3      34
# 4      39
# 5      51
# 6      48
# 7      62
# 8      75
# 9      81
# 10     71
# 11     83
# 12     97
# 13    100
# 14     98
# Name: a, dtype: int64
#
# letters_equal_area['a']:
# 0     10
# 1     10
# 2     10
# 3     12
# 4     14
# 5     19
# 6     18
# 7     23
# 8     28
# 9     30
# 10    26
# 11    31
# 12    36
# 13    37
# 14    37
# Name: a, dtype: int64
#
# letters_compromise['a']:
# 0     19
# 1     19
# 2     19
# 3     23
# 4     26
# 5     35
# 6     33
# 7     42
# 8     51
# 9     55
# 10    48
# 11    57
# 12    66
# 13    68
# 14    67
# Name: a, dtype: int64
#
# letters_stats:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a    557452       13     5188938  11.378232        860  #b10026
# b     66062        7      415288   0.910638        605  #fed976
# c    238222        0     1444104   3.166611        549  #fc4e2a
# d    401340        0     3056649   6.702578        700  #e31a1c
# e    651397       12     8024389  17.595770       1142  #b10026
# f     47904        0      222317   0.487494        408  #ffeda0
# g     35733        6      315130   0.691013        830  #fed976
# h     73746        0      422040   0.925444        516  #fed976
# i    234211        9     2106498   4.619100        872  #fc4e2a
# j     12817       11      104990   0.230221        780  #ffeda0
# k      1206        0        7439   0.016312        539  #ffffcc
# l    378558        4     3747029   8.216434        913  #e31a1c
# m    121337        0     1076621   2.360800        830  #fd8d3c
# n    378235       14     3473146   7.615867        850  #e31a1c
# o    461921       13     3945049   8.650649        796  #e31a1c
# p    293193        0     1123295   2.463146        327  #fd8d3c
# q    140503        1      713375   1.564279        451  #feb24c
# r    249752       10     2322789   5.093380        869  #e31a1c
# s    584414       14     3648829   8.001102        551  #e31a1c
# t    171376        8     1526625   3.347562        853  #fc4e2a
# u    274419        5     2105280   4.616429        741  #fc4e2a
# v     37209        0      276710   0.606766        689  #fed976
# w       501        0        2549   0.005589        448  #ffffcc
# x     13485        2       47472   0.104096        344  #ffeda0
# y     20320       10      193309   0.423885        885  #ffeda0
# z     16589       10       94219   0.206602        536  #ffeda0
#
# Letters_overall:
# {'total_freq': 45604079, 'max_area': 1142, 'max_equal_area': 349, 'max_letter': 'e', 'max_freq': 651397, 'max_compromise': 100, 'max_pct_for_legend': 18, 'max_pct': 17.595770325720206}
#
# ==================================
#
#
# Language:
#  Italian
# letters['a']:
# 0     194496
# 1     199862
# 2     198036
# 3     195291
# 4     177403
# 5     206499
# 6     219499
# 7     244328
# 8     283186
# 9     271625
# 10    323938
# 11    293472
# 12    338649
# 13    474383
# 14    518444
# Name: a, dtype: int64
#
# letters_norm['a']:
# 0      37
# 1      38
# 2      38
# 3      37
# 4      34
# 5      39
# 6      42
# 7      47
# 8      54
# 9      52
# 10     62
# 11     56
# 12     65
# 13     91
# 14    100
# Name: a, dtype: int64
#
# letters_equal_area['a']:
# 0     10
# 1     11
# 2     11
# 3     10
# 4     10
# 5     11
# 6     12
# 7     13
# 8     16
# 9     15
# 10    18
# 11    16
# 12    19
# 13    26
# 14    29
# Name: a, dtype: int64
#
# letters_compromise['a']:
# 0     23
# 1     24
# 2     24
# 3     23
# 4     22
# 5     25
# 6     27
# 7     30
# 8     35
# 9     33
# 10    40
# 11    36
# 12    42
# 13    58
# 14    64
# Name: a, dtype: int64
#
# letters_stats:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a    518444       14     4139111  10.235048        723  #b10026
# b     29407        5      289812   0.716637        935  #fed976
# c    315313        0     1593342   3.939960        449  #fc4e2a
# d    381629        0     2268938   5.610550        535  #e31a1c
# e    686731       14     4636578  11.465167        612  #b10026
# f     63295        0      303080   0.749446        422  #fed976
# g     63124        6      556088   1.375075        829  #feb24c
# h    101406        5      672190   1.662168        643  #feb24c
# i    556280       14     5282604  13.062637        876  #b10026
# j       522        0        1912   0.004728        307  #ffffcc
# k      1110        0        7516   0.018585        593  #ffffcc
# l    319857       10     3276175   8.101210        969  #e31a1c
# m    106665        0      958818   2.370931        841  #fd8d3c
# n    361144       11     3118377   7.711013        821  #e31a1c
# o    538305       14     3381848   8.362515        566  #e31a1c
# p    290735        0     1185303   2.930976        350  #fd8d3c
# q     66154        0      179307   0.443384        215  #ffeda0
# r    261457       11     2335041   5.774007        851  #e31a1c
# s    269027        0     1965214   4.859512        672  #fc4e2a
# t    280790       11     2131157   5.269850        736  #e31a1c
# u    216977        3     1374654   3.399196        607  #fc4e2a
# v     56668        0      505465   1.249896        833  #feb24c
# w       494        0        2892   0.007151        520  #ffffcc
# x       403        5        3661   0.009053        830  #ffffcc
# y       690       14        3890   0.009619        499  #ffffcc
# z     48552        8      267589   0.661685        542  #fed976
#
# Letters_overall:
# {'total_freq': 40440562, 'max_area': 969, 'max_equal_area': 450, 'max_letter': 'e', 'max_freq': 686731, 'max_compromise': 100, 'max_pct_for_legend': 14, 'max_pct': 13.062637457906742}
#
# ==================================
#
#
# Language:
#  Portuguese
# letters['a']:
# 0     226409
# 1     217726
# 2     202809
# 3     226920
# 4     269768
# 5     333402
# 6     324308
# 7     318301
# 8     323646
# 9     384580
# 10    371762
# 11    474816
# 12    558688
# 13    516147
# 14    482506
# Name: a, dtype: int64
#
# letters_norm['a']:
# 0      40
# 1      38
# 2      36
# 3      40
# 4      48
# 5      59
# 6      58
# 7      56
# 8      57
# 9      68
# 10     66
# 11     84
# 12    100
# 13     92
# 14     86
# Name: a, dtype: int64
#
# letters_equal_area['a']:
# 0     14
# 1     14
# 2     13
# 3     14
# 4     17
# 5     21
# 6     21
# 7     21
# 8     21
# 9     25
# 10    24
# 11    31
# 12    37
# 13    34
# 14    32
# Name: a, dtype: int64
#
# letters_compromise['a']:
# 0     27
# 1     26
# 2     24
# 3     27
# 4     32
# 5     40
# 6     39
# 7     38
# 8     39
# 9     46
# 10    45
# 11    57
# 12    68
# 13    63
# 14    59
# Name: a, dtype: int64
#
# letters_stats:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a    558688       12     5231788  12.862688        865  #b10026
# b     38876        6      289241   0.711118        710  #fed976
# c    224514        0     1345968   3.309149        544  #fc4e2a
# d    442054        0     3235147   7.953818        677  #e31a1c
# e    518213       12     5731826  14.092064       1026  #b10026
# f     73794        0      310829   0.764193        367  #fed976
# g     33105        6      318189   0.782288        907  #fed976
# h     30270        9      248525   0.611015        782  #fed976
# i    217423        8     2006753   4.933732        893  #fc4e2a
# j     14140        0      125653   0.308926        831  #ffeda0
# k       934        0        6182   0.015199        579  #ffffcc
# l     83208        4      764806   1.880325        860  #feb24c
# m    208061       10     2165565   5.324181        961  #e31a1c
# n    216841        4     1950272   4.794870        854  #fc4e2a
# o    621859       14     4741481  11.657237        697  #b10026
# p    295166        0     1126033   2.768425        326  #fd8d3c
# q    142480        0      689803   1.695925        428  #feb24c
# r    223342       10     2330250   5.729070        972  #e31a1c
# s    586829       14     3768458   9.264997        569  #b10026
# t    177022        9     1673660   4.114801        908  #fc4e2a
# u    241065        5     1982054   4.873008        789  #fc4e2a
# v     43293        0      428361   1.053153        933  #feb24c
# w       495        0        2425   0.005962        430  #ffffcc
# x     17306        2       69637   0.171207        395  #ffeda0
# y       621       14        3111   0.007649        440  #ffffcc
# z     17531        8      128124   0.315001        687  #ffeda0
#
# Letters_overall:
# {'total_freq': 40674141, 'max_area': 1026, 'max_equal_area': 314, 'max_letter': 'o', 'max_freq': 621859, 'max_compromise': 100, 'max_pct_for_legend': 15, 'max_pct': 14.09206404629418}
#
# ==================================
#
#
# Language:
#  Polish
# letters['a']:
# 0      8867
# 1     16696
# 2     33949
# 3     48287
# 4     57234
# 5     56856
# 6     54794
# 7     67055
# 8     76962
# 9     76506
# 10    69739
# 11    58836
# 12    56285
# 13    73531
# 14    89823
# Name: a, dtype: int64
#
# letters_norm['a']:
# 0       9
# 1      18
# 2      37
# 3      53
# 4      63
# 5      63
# 6      61
# 7      74
# 8      85
# 9      85
# 10     77
# 11     65
# 12     62
# 13     81
# 14    100
# Name: a, dtype: int64
#
# letters_equal_area['a']:
# 0      2
# 1      4
# 2      8
# 3     12
# 4     14
# 5     14
# 6     14
# 7     17
# 8     20
# 9     20
# 10    18
# 11    15
# 12    14
# 13    19
# 14    23
# Name: a, dtype: int64
#
# letters_compromise['a']:
# 0      5
# 1     11
# 2     22
# 3     32
# 4     38
# 5     38
# 6     37
# 7     45
# 8     52
# 9     52
# 10    47
# 11    40
# 12    38
# 13    50
# 14    61
# Name: a, dtype: int64
#
# letters_stats:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a     89823       14      845420  10.816480        878  #b10026
# b     12747        1      112233   1.435932        816  #feb24c
# c     33416       10      270986   3.467052        776  #fc4e2a
# d     35888        0      322945   4.131826        835  #fc4e2a
# e    112751       14      801699  10.257105        650  #b10026
# f      4602        0       18149   0.232202        337  #ffeda0
# g     10731       10      101355   1.296757        901  #feb24c
# h     28372       14       76731   0.981712        209  #fed976
# i     62568       12      590059   7.549338        892  #e31a1c
# j     29119       12      237517   3.038842        735  #fc4e2a
# k     33027        0      246784   3.157406        674  #fc4e2a
# l     19213        8      159550   2.041316        802  #fd8d3c
# m     29506       14      246929   3.159261        744  #fc4e2a
# n     50838       11      545679   6.981531       1018  #e31a1c
# o     58872        8      714560   9.142230       1136  #b10026
# p     80410        0      259657   3.322106        265  #fc4e2a
# q        12        3          76   0.000972        587  #ffffcc
# r     48970        3      362472   4.637543        710  #fc4e2a
# s     47435        0      361699   4.627653        700  #fc4e2a
# t     46328        3      412272   5.274694        828  #e31a1c
# u     28722       14      205144   2.624655        636  #fd8d3c
# v       155        0         939   0.012014        544  #ffffcc
# w     30259        0      247126   3.161782        737  #fc4e2a
# x        60       14         520   0.006653        780  #ffffcc
# y     45598       14      289579   3.704934        577  #fc4e2a
# z     32732        8      385956   4.938002       1107  #fc4e2a
#
# Letters_overall:
# {'total_freq': 7816036, 'max_area': 1136, 'max_equal_area': 543, 'max_letter': 'e', 'max_freq': 112751, 'max_compromise': 100, 'max_pct_for_legend': 11, 'max_pct': 10.816480374450681}
#
# ==================================
#
#
# Language:
#  Finnish
# letters['a']:
# 0      87588
# 1     201364
# 2     272378
# 3     247432
# 4     210337
# 5     184343
# 6     168010
# 7     216807
# 8     257914
# 9     279544
# 10    303756
# 11    412423
# 12    543674
# 13    618222
# 14    712386
# Name: a, dtype: int64
#
# letters_norm['a']:
# 0      12
# 1      28
# 2      38
# 3      34
# 4      29
# 5      25
# 6      23
# 7      30
# 8      36
# 9      39
# 10     42
# 11     57
# 12     76
# 13     86
# 14    100
# Name: a, dtype: int64
#
# letters_equal_area['a']:
# 0      4
# 1     11
# 2     16
# 3     14
# 4     12
# 5     10
# 6      9
# 7     12
# 8     15
# 9     16
# 10    17
# 11    24
# 12    32
# 13    36
# 14    42
# Name: a, dtype: int64
#
# letters_compromise['a']:
# 0      8
# 1     19
# 2     27
# 3     24
# 4     20
# 5     17
# 6     16
# 7     21
# 8     25
# 9     27
# 10    29
# 11    40
# 12    54
# 13    61
# 14    71
# Name: a, dtype: int64
#
# letters_stats:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a    712386       14     4716178  17.274633        599  #b10026
# b      4488        0       15669   0.057393        291  #ffffcc
# c      1108        0        8542   0.031288        711  #ffffcc
# d     37642        9      271936   0.996060        708  #fed976
# e    217390       12     2519338   9.227946       1085  #b10026
# f      1288        0        8442   0.030922        592  #ffffcc
# g      3888        4       29082   0.106523        714  #ffeda0
# h     68517        0      430641   1.577372        571  #feb24c
# i    262072        5     2667595   9.770989        980  #b10026
# j    178629        0     1022497   3.745249        515  #fc4e2a
# k    199482        0     1143868   4.189812        516  #fc4e2a
# l    115915        8     1177624   4.313455        988  #fc4e2a
# m    135811        0      912381   3.341911        616  #fc4e2a
# n    650951       14     2622711   9.606586        342  #b10026
# o    254980        3     2093658   7.668746        776  #e31a1c
# p    109224        0      342203   1.253437        256  #feb24c
# q        57        7         276   0.001011        455  #ffffcc
# r     83670        3      454639   1.665273        520  #feb24c
# s    223357       11     1951941   7.149659        823  #e31a1c
# t    256136        7     2711167   9.930587        987  #b10026
# u    134958        3     1055198   3.865028        758  #fc4e2a
# v    121868        0      653844   2.394930        480  #fd8d3c
# w       845        0        4123   0.015102        424  #ffffcc
# x       152        3         724   0.002652        447  #ffffcc
# y     52792        5      483877   1.772367        863  #feb24c
# z       330        6        3023   0.011073        850  #ffffcc
#
# Letters_overall:
# {'total_freq': 27301177, 'max_area': 1085, 'max_equal_area': 423, 'max_letter': 'a', 'max_freq': 712386, 'max_compromise': 100, 'max_pct_for_legend': 18, 'max_pct': 17.274632518590682}
#
# ==================================

# %% [markdown]
# #### Make plots:

# %%
save_plots = True

column_list = list('abcdefghijklmnopqrstuvwxyz')
x_length = b_len

import matplotlib.pyplot as plt

for language in language_list:

    
    letters_compromise = pd.read_pickle(nb_path + '/' + language + '_letters_compromise.pickle')
    letters_stats = pickle.load(open(nb_path + '/' + language + '_letters_stats.pickle', 'r'))
    
    fig, axes = plt.subplots(26, 1, figsize=(12, 90))
    #plt.title("Title", size=18, color='k')
    
    for pos in range(len(column_list)):
        ltr = column_list[pos]
        axes[pos].plot(range(x_length), letters_compromise[ltr], color='k', linewidth = 3, label = ltr)
        axes[pos].set_ylim(0,100)  
        fill_color = letters_stats['color'].ix[ltr]
        axes[pos].fill_between(range(x_length), letters_compromise[ltr], color=fill_color, interpolate=True)
        axes[pos].set_xticks([])
        axes[pos].set_yticks([])
        axes[pos].set_xticklabels([], size=0)
        axes[pos].set_yticklabels([])
        axes[pos].get_xaxis().set_visible(False)
        axes[pos].set_ylabel(ltr+'       ', size=24, rotation='horizontal')
        plt.subplots_adjust(hspace=0.1)
    
    plot_name = nb_path + '/plot_' + language + '.png'
    
    if save_plots == True:
        plt.savefig(plot_name)

# %%
#verifications
p = pickle.load(open(nb_path + '/Polish_letters_stats.pickle', 'r'))

# %%
p
# Out:
#    max_freq  max_bin  total_freq   pct_freq  norm_area    color
# a     89823       14      845420  10.816480        878  #b10026
# b     12747        1      112233   1.435932        816  #feb24c
# c     33416       10      270986   3.467052        776  #fc4e2a
# d     35888        0      322945   4.131826        835  #fc4e2a
# e    112751       14      801699  10.257105        650  #b10026
# f      4602        0       18149   0.232202        337  #ffeda0
# g     10731       10      101355   1.296757        901  #feb24c
# h     28372       14       76731   0.981712        209  #fed976
# i     62568       12      590059   7.549338        892  #e31a1c
# j     29119       12      237517   3.038842        735  #fc4e2a
# k     33027        0      246784   3.157406        674  #fc4e2a
# l     19213        8      159550   2.041316        802  #fd8d3c
# m     29506       14      246929   3.159261        744  #fc4e2a
# n     50838       11      545679   6.981531       1018  #e31a1c
# o     58872        8      714560   9.142230       1136  #b10026
# p     80410        0      259657   3.322106        265  #fc4e2a
# q        12        3          76   0.000972        587  #ffffcc
# r     48970        3      362472   4.637543        710  #fc4e2a
# s     47435        0      361699   4.627653        700  #fc4e2a
# t     46328        3      412272   5.274694        828  #e31a1c
# u     28722       14      205144   2.624655        636  #fd8d3c
# v       155        0         939   0.012014        544  #ffffcc
# w     30259        0      247126   3.161782        737  #fc4e2a
# x        60       14         520   0.006653        780  #ffffcc
# y     45598       14      289579   3.704934        577  #fc4e2a
# z     32732        8      385956   4.938002       1107  #fc4e2a
